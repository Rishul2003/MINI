# %% [markdown]
# #### Importing the dataset
# #### Source :

# %%
import pandas as pd
# reading file
dataset = pd.read_csv('../dataset/data.csv', sep='|')

# %% [markdown]
# #### About the dataset

# %%
dataset.head()    #Top 5 row of the dataset
# Out:
#            Name                               md5  Machine  \
# 0   memtest.exe  631ea355665f28d4707448e442fbf5b8      332
# 1       ose.exe  9d10f99a6712e28f8acd5641e3a7ea6b      332
# 2     setup.exe  4d92f518527353c0db88a70fddcfd390      332
# 3      DW20.EXE  a41e524f8d45f0074fd07805ff0c9b12      332
# 4  dwtrig20.exe  c87e561258f2f8650cef999bf643a731      332
#
#    SizeOfOptionalHeader  Characteristics  MajorLinkerVersion  \
# 0                   224              258                   9
# 1                   224             3330                   9
# 2                   224             3330                   9
# 3                   224              258                   9
# 4                   224              258                   9
#
#    MinorLinkerVersion  SizeOfCode  SizeOfInitializedData  \
# 0                   0      361984                 115712
# 1                   0      130560                  19968
# 2                   0      517120                 621568
# ...

# %%
dataset.tail()     #Last 5 row of the dataset
# Out:
#                                                Name  \
# 138042  VirusShare_8e292b418568d6e7b87f2a32aee7074b
# 138043  VirusShare_260d9e2258aed4c8a3bbd703ec895822
# 138044  VirusShare_8d088a51b7d225c9f5d11d239791ec3f
# 138045  VirusShare_4286dccf67ca220fe67635388229a9f3
# 138046  VirusShare_d7648eae45f09b3adb75127f43be6d11
#
#                                      md5  Machine  SizeOfOptionalHeader  \
# 138042  8e292b418568d6e7b87f2a32aee7074b      332                   224
# 138043  260d9e2258aed4c8a3bbd703ec895822      332                   224
# 138044  8d088a51b7d225c9f5d11d239791ec3f      332                   224
# 138045  4286dccf67ca220fe67635388229a9f3      332                   224
# 138046  d7648eae45f09b3adb75127f43be6d11      332                   224
#
#         Characteristics  MajorLinkerVersion  MinorLinkerVersion  SizeOfCode  \
# 138042              258                  11                   0      205824
# ...

# %%
dataset.columns    # name of the columns
# Out:
# Index(['Name', 'md5', 'Machine', 'SizeOfOptionalHeader', 'Characteristics',
#        'MajorLinkerVersion', 'MinorLinkerVersion', 'SizeOfCode',
#        'SizeOfInitializedData', 'SizeOfUninitializedData',
#        'AddressOfEntryPoint', 'BaseOfCode', 'BaseOfData', 'ImageBase',
#        'SectionAlignment', 'FileAlignment', 'MajorOperatingSystemVersion',
#        'MinorOperatingSystemVersion', 'MajorImageVersion', 'MinorImageVersion',
#        'MajorSubsystemVersion', 'MinorSubsystemVersion', 'SizeOfImage',
#        'SizeOfHeaders', 'CheckSum', 'Subsystem', 'DllCharacteristics',
#        'SizeOfStackReserve', 'SizeOfStackCommit', 'SizeOfHeapReserve',
#        'SizeOfHeapCommit', 'LoaderFlags', 'NumberOfRvaAndSizes', 'SectionsNb',
#        'SectionsMeanEntropy', 'SectionsMinEntropy', 'SectionsMaxEntropy',
#        'SectionsMeanRawsize', 'SectionsMinRawsize', 'SectionMaxRawsize',
#        'SectionsMeanVirtualsize', 'SectionsMinVirtualsize',
# ...

# %%
dataset.describe(include="all")    # summary of numeric attributes
# Out:
#               Name                               md5        Machine  \
# count       138047                            138047  138047.000000
# unique      107488                            138047            NaN
# top     mshtml.dll  631ea355665f28d4707448e442fbf5b8            NaN
# freq           187                                 1            NaN
# mean           NaN                               NaN    4259.069274
# std            NaN                               NaN   10880.347245
# min            NaN                               NaN     332.000000
# 25%            NaN                               NaN     332.000000
# 50%            NaN                               NaN     332.000000
# 75%            NaN                               NaN     332.000000
# max            NaN                               NaN   34404.000000
#
#         SizeOfOptionalHeader  Characteristics  MajorLinkerVersion  \
# count          138047.000000    138047.000000       138047.000000
# ...

# %%
dataset.info()    # info about the whole dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138047 entries, 0 to 138046
# Data columns (total 57 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Name                         138047 non-null  object
#  1   md5                          138047 non-null  object
#  2   Machine                      138047 non-null  int64
#  3   SizeOfOptionalHeader         138047 non-null  int64
#  4   Characteristics              138047 non-null  int64
#  5   MajorLinkerVersion           138047 non-null  int64
#  6   MinorLinkerVersion           138047 non-null  int64
#  7   SizeOfCode                   138047 non-null  int64
#  8   SizeOfInitializedData        138047 non-null  int64
#  9   SizeOfUninitializedData      138047 non-null  int64
#  10  AddressOfEntryPoint          138047 non-null  int64
#  11  BaseOfCode                   138047 non-null  int64
# ...

# %%
dataset["legitimate"].value_counts()    # count of malware (0) and legit (1) files in dataset
# Out:
# 0    96724
# 1    41323
# Name: legitimate, dtype: int64

# %% [markdown]
# #### Visualization

# %%
import matplotlib.pyplot as plt

dataset["legitimate"].value_counts().plot(kind="pie",autopct="%1.1f%%")
plt.show()

# %%
import os
import pandas
import numpy
import pickle
import pefile
import sklearn.ensemble as ek
from sklearn.feature_selection import SelectFromModel
import joblib
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn import svm
import sklearn.metrics as metrics
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# #### Feature Selection

# %%
# Feature
X = dataset.drop(['Name','md5','legitimate'],axis=1).values    #Droping this because classification model will not accept object type elements (float and int only)
# Target variable
y = dataset['legitimate'].values

# %% [markdown]
# #### Data Fitting and choosing the important variables

# %%
# Fit an Extra Trees classifier to the data and perform feature selection
extratrees = ek.ExtraTreesClassifier().fit(X, y)
# Use SelectFromModel to select features based on the fitted classifier
model = SelectFromModel(extratrees, prefit=True)
# Transform the original feature matrix to contain only selected features
X_new = model.transform(X)
# Determine the number of selected features
nbfeatures = X_new.shape[1]

# %%
#Number of important features
nbfeatures
# Out:
# 13

# %%
#splitting the data (70% - training and 30% - testing)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_new, y ,test_size=0.29, stratify = y)

# %%
features = []
index = numpy.argsort(extratrees.feature_importances_)[::-1][:nbfeatures]

# %% [markdown]
# #### All the required features

# %%
for f in range(nbfeatures):
    print("%d. feature %s" % (f + 1, dataset.columns[2+index[f]]))
    features.append(dataset.columns[2+f])
# Out:
# 1. feature DllCharacteristics
# 2. feature Characteristics
# 3. feature Machine
# 4. feature Subsystem
# 5. feature ImageBase
# 6. feature SectionsMaxEntropy
# 7. feature MajorSubsystemVersion
# 8. feature VersionInformationSize
# 9. feature ResourcesMinEntropy
# 10. feature SizeOfOptionalHeader
# 11. feature ResourcesMaxEntropy
# 12. feature SizeOfStackReserve
# 13. feature MajorOperatingSystemVersion

# %% [markdown]
# #### Testing which Classifier will give better result

# %%
model = { 
    "DecisionTree": DecisionTreeClassifier(max_depth=10),
    "RandomForest": ek.RandomForestClassifier(n_estimators=50),
    # "SVM": svm.SVC(),
    "GradientBoosting": ek.GradientBoostingClassifier(n_estimators=100),
    # "LogisticRegression": LogisticRegression()
}

# %%
from sklearn.metrics import confusion_matrix

results = {}
for algo in model:
    clf = model[algo]
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    cm = confusion_matrix(y_test, y_pred)
    accuracy = clf.score(X_test, y_test)
    print("%s : Accuracy = %s" % (algo, accuracy))
    print("Confusion Matrix for %s:" % algo)
    print(cm)
    results[algo] = {'accuracy': accuracy, 'confusion_matrix': cm}
# Out:
# DecisionTree : Accuracy = 0.9906079832142679
# Confusion Matrix for DecisionTree:
# [[27870   180]
#  [  196 11788]]
# RandomForest : Accuracy = 0.9938802018284458
# Confusion Matrix for RandomForest:
# [[27918   132]
#  [  113 11871]]
# GradientBoosting : Accuracy = 0.9896088324923815
# Confusion Matrix for GradientBoosting:
# [[27850   200]
#  [  216 11768]]

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 6), dpi=100)
for algo, clf in model.items():
    clf.fit(X_train, y_train)
    y_pred = clf.predict_proba(X_test)[:, 1]  # Use predict_proba for calculating probabilities of positive class
    fpr, tpr, thresholds = roc_curve(y_test, y_pred)
    auc_val = auc(fpr, tpr)

    plt.plot(fpr, tpr, linestyle='-', label=f'{algo} (AUC = {auc_val:.7f})')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Different Models')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, roc_auc_score
metrics_table = {
    'Algorithm': [],
    'Accuracy': [],
    'Precision': [],
    'Recall': [],
    'F1 Score': [],
    'AUC-ROC': []
}

for algo in model:
    clf = model[algo]
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    
    # Calculate confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    
    # Calculate accuracy
    accuracy = clf.score(X_test, y_test)
    
    # Calculate precision
    precision = precision_score(y_test, y_pred)
    
    # Calculate recall
    recall = recall_score(y_test, y_pred)
    
    # Calculate F1 score
    f1 = f1_score(y_test, y_pred)
    
    # Calculate AUC-ROC
    y_score = clf.predict_proba(X_test)[:, 1]  # For binary classification
    auc_roc = roc_auc_score(y_test, y_score)
    
    # Print metrics
    print("%s : Accuracy = %s, Precision = %s, Recall = %s, F1 Score = %s, AUC-ROC = %s" % (algo, accuracy, precision, recall, f1, auc_roc))
    
    # Store metrics in results dictionary
    results[algo] = {'accuracy': accuracy, 'precision': precision, 'recall': recall, 'f1_score': f1, 'auc_roc': auc_roc}
    
    # Append metrics to metrics table
    metrics_table['Algorithm'].append(algo)
    metrics_table['Accuracy'].append(accuracy)
    metrics_table['Precision'].append(precision)
    metrics_table['Recall'].append(recall)
    metrics_table['F1 Score'].append(f1)
    metrics_table['AUC-ROC'].append(auc_roc)

metrics_df = pd.DataFrame(metrics_table)

# Print or do further operations with metrics_df
print(metrics_df)
# Out:
# DecisionTree : Accuracy = 0.9907328770545036, Precision = 0.9852093256455252, Recall = 0.9838117489986649, F1 Score = 0.984510041334391, AUC-ROC = 0.9945437484679515
# RandomForest : Accuracy = 0.9940050956686817, Precision = 0.9892517913681054, Recall = 0.990737650200267, F1 Score = 0.9899941632619029, AUC-ROC = 0.9991467173105436
# GradientBoosting : Accuracy = 0.9896338112604286, Precision = 0.9832901662628457, Recall = 0.9820594125500668, F1 Score = 0.9826744040412475, AUC-ROC = 0.9989741967305189
#           Algorithm  Accuracy  Precision    Recall  F1 Score   AUC-ROC
# 0      DecisionTree  0.990733   0.985209  0.983812  0.984510  0.994544
# 1      RandomForest  0.994005   0.989252  0.990738  0.989994  0.999147
# 2  GradientBoosting  0.989634   0.983290  0.982059  0.982674  0.998974

# %%
# Function to plot the metrics table
def plot_metrics_table(metrics_df):
    # Create a figure and axis
    fig, ax = plt.subplots(figsize=(10, 6))
    
    # Hide axes
    ax.axis('off')
    
    # Plot table
    ax.table(cellText=metrics_df.values,
             colLabels=metrics_df.columns,
             cellLoc='center',
             loc='center')
    
    # Set title
    ax.set_title('Metrics Table')
    
    # Show plot
    plt.show()

# Call function to plot the metrics table
plot_metrics_table(metrics_df)

# %%
winner = max(results, key=lambda x: results[x]['accuracy'])
print("Using", winner, "for classification, with", len(features), 'features.')
# Out:
# Using RandomForest for classification, with 13 features.

# %% [markdown]
# #### Saving the machine as classifier.pkl and features to be extracted as features.pkl

# %%
# Save the winning model to a file
joblib.dump(model[winner], 'classifier.pkl')

# Save the features list to a file using pickle
with open('features.pkl', 'wb') as f:
    # Serialize the features list and write it to the file
    pickle.dump(features, f)
